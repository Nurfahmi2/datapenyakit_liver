# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn import tree

# %% [markdown]
# saya menggunakan Pandas untuk manipulasi data dan analisis data. NumPy adalah pustaka utama untuk komputasi ilmiah dengan Python. "from sklearn.model_selection import train_test_split" fungsi ini digunakan untuk membagi dataset menjadi subset pelatihan dan pengujian. Ini adalah langkah penting dalam pembelajaran mesin untuk mengevaluasi kinerja model. Metode Evaluasi, fungsi-fungsi ini digunakan untuk mengevaluasi kinerja model. accuracy_score, menghitung akurasi prediksi model. classification_report, memberikan laporan teks yang menunjukkan precision, recall, F1-score, dan support untuk setiap kelas.
# confusion_matrix, menyediakan matriks konfusi yang membantu dalam memahami kinerja model secara lebih rinci. Matplotlib adalah pustaka utama untuk membuat visualisasi data dalam Python. Plotting berfungsi pembuatan berbagai jenis grafik seperti garis, batang, histogram, scatter plot. Visualisasi Model, modul ini digunakan untuk berbagai fungsi yang berkaitan dengan pohon keputusan, termasuk visualisasi pohon yang terlatih.
# Tree Plotting, fungsi seperti tree.plot_tree() dapat digunakan untuk menggambarkan pohon keputusan yang telah dilatih, yang membantu dalam memahami keputusan yang dibuat oleh model.

# %%
#Loading data
data = pd.read_csv("C:/Users/Nuria/Downloads/Data Pasien penyakit liver.csv")
data.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       0              0.7               0.1                   187
# 1   62       1             10.9               5.5                   699
# 2   62       1              7.3               4.1                   490
# 3   58       1              1.0               0.4                   182
# 4   72       1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %% [markdown]
# Alasan saya mengambil dataset data pasien penyakit liver karena memiliki berbagai alasan yang penting, baik dari sisi klinis, penelitian, maupun pengembangan teknologi.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         579 non-null    int64
#  1   Gender                      579 non-null    int64
#  2   Total_Bilirubin             579 non-null    float64
#  3   Direct_Bilirubin            579 non-null    float64
#  4   Alkaline_Phosphotase        579 non-null    int64
#  5   Alamine_Aminotransferase    579 non-null    int64
#  6   Aspartate_Aminotransferase  579 non-null    int64
#  7   Total_Protiens              579 non-null    float64
#  8   Albumin                     579 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     579 non-null    int64
# dtypes: float64(5), int64(6)
# memory usage: 49.9 KB

# %% [markdown]
# Fungsi data.info() adalah metode yang disediakan oleh pustaka Pandas untuk objek DataFrame. Metode ini memberikan ringkasan informasi mengenai DataFrame, yang sangat berguna untuk memahami struktur dan karakteristik data yang Anda kerjakan.

# %%
print(data.isnull().sum())
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %% [markdown]
# Fungsi print(data.isnull().sum()) dalam konteks penggunaan Pandas pada DataFrame berguna untuk mengidentifikasi dan menampilkan jumlah nilai yang hilang (missing values) di setiap kolom.

# %%
#Jika ada missing value, hapus baris yang mengandung missing values
data.dropna(inplace=True)

# %%
#Mendefinisikan fitur dan target
x = data.drop(["Dataset"], axis=1)
y = data["Dataset"]

# %%
# Membagi data menjadi train dan test set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Membuat model Decision Tree
model = DecisionTreeClassifier(random_state=42)

# %%
# Melatih model
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Prediksi dengan data uji
y_pred = model.predict(x_test)

# %%
# Evaluasi model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print('Classification Report:')
print(classification_report(y_test, y_pred))
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.5862068965517241
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.64      0.77      0.70        73
#            2       0.41      0.28      0.33        43
#
#     accuracy                           0.59       116
#    macro avg       0.53      0.52      0.52       116
# weighted avg       0.56      0.59      0.56       116
#
# Confusion Matrix:
# [[56 17]
#  [31 12]]

# %%
# Visualisasi Decision Tree
plt.figure(figsize=(20,10))
tree.plot_tree(model, feature_names=X.columns, class_names=[str(i) for i in sorted(y.unique())], filled=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Visualisasi Decision Tree
#       2 plt.figure(figsize=(20,10))
# ----> 3 tree.plot_tree(model, feature_names=X.columns, class_names=[str(i) for i in sorted(y.unique())], filled=True)
#       4 plt.show()
#
# NameError: name 'X' is not defined

# %%
# Visualisasi Decision Tree
plt.figure(figsize=(20,10))
tree.plot_tree(model, feature_names=X.columns, class_names=[str(i) for i in sorted(y.unique())], filled=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Visualisasi Decision Tree
#       2 plt.figure(figsize=(20,10))
# ----> 3 tree.plot_tree(model, feature_names=X.columns, class_names=[str(i) for i in sorted(y.unique())], filled=True)
#
# NameError: name 'X' is not defined

# %%
# Visualisasi Decision Tree
plt.figure(figsize=(20,10))
tree.plot_tree(model, feature_names=x.columns, class_names=[str(i) for i in sorted(y.unique())], filled=True)
plt.show()
